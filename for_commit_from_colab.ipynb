# %%
# reference : https://inistory.tistory.com/110

from google.colab import drive
ROOT = "/content/drive"
drive.mount(ROOT)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from os.path import join  


# path to your project on Google Drive
MY_GOOGLE_DRIVE_PATH = '/content/drive/MyDrive/GitHub/CS231n' 
# replace with your Github username 
GIT_USERNAME = "temp-jm" 
# definitely replace with your
GIT_TOKEN = "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"  
# Replace with your github repository in this case we want 
# to clone deep-learning-v2-pytorch repository
GIT_REPOSITORY = "CS231n"

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

# It's good to print out the value if you are not sure 
print("PROJECT_PATH: ", PROJECT_PATH)

# In case we haven't created the folder already; we will create a folder in the project path 
# !mkdir "{PROJECT_PATH}"    

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_USERNAME + ":" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# PROJECT_PATH:  /content/drive/MyDrive/GitHub/CS231n
# GIT_PATH:  https://temp-jm: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@github.com/temp-jm/CS231n.git

# %%
# %cd "{PROJECT_PATH}"

# Change directory to the location defined in project_path
#!git clone "{GIT_PATH}"
# clone the github repository
#git init
#!git fetch --all
#!git reset --hard origin/main
# Out:
# /content/drive/MyDrive/GitHub/CS231n

# %%
# !git init
# !git config --global user.email "{98165579+temp-jm@users.noreply.github.com}"
# !git config --global user.name  "{temp-jm}"
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/GitHub/CS231n/.git/

# %%
# !git add .

# %%
#!echo "#colab test" >> testtest.md
# !git add .
# !git commit -m "test commit"
# !git branch -M main
# !git remote add origin "{GIT_PATH}"
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/.git/
# [main 4e901fe] test commit
#  1 file changed, 1 insertion(+)
# To https://github.com/temp-jm/CS231n.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://temp-jm: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@github.com/temp-jm/CS231n.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git remote rm origin
# !git remote add origin "{GIT_PATH}"
# !git remote -v
# Out:
# origin	https://temp-jm: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@github.com/temp-jm/CS231n.git (fetch)
# origin	https://temp-jm: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@github.com/temp-jm/CS231n.git (push)

# %%
# !git pull origin main
# Out:
# ...
# remote: Enumerating objects: 108, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 108 (delta 23), reused 7 (delta 2), pack-reused 0
# Receiving objects: 100% (108/108), 6.60 MiB | 8.28 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# From https://github.com/temp-jm/CS231n
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main
# fatal: refusing to merge unrelated histories

# %%
# !git add . 
# !git commit -m "update from g-drive_test"
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# commit message
# !git push
